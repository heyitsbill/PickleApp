# %%
import cv2
import numpy as np
court_picture_path = '/home/billf/SeniorProject/data/court_photos/pro_court_1_crop.png'
court_picture = cv2.imread(court_picture_path)

# %%
cv2.imshow('court', court_picture)
cv2.waitKey(0)
cv2.destroyAllWindows() 
# cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x555a77645f00) is not the object's thread (0x555a77d4d180).
# Cannot move to target thread (0x555a77645f00)
#
# QObject::moveToThread: Current thread (0x555a77645f00) is not the object's thread (0x555a77d4d180).
# Cannot move to target thread (0x555a77645f00)
#
# QObject::moveToThread: Current thread (0x555a77645f00) is not the object's thread (0x555a77d4d180).
# Cannot move to target thread (0x555a77645f00)
#
# QObject::moveToThread: Current thread (0x555a77645f00) is not the object's thread (0x555a77d4d180).
# Cannot move to target thread (0x555a77645f00)
#
# QObject::moveToThread: Current thread (0x555a77645f00) is not the object's thread (0x555a77d4d180).
# Cannot move to target thread (0x555a77645f00)
#
# QObject::moveToThread: Current thread (0x555a77645f00) is not the object's thread (0x555a77d4d180).
# Cannot move to target thread (0x555a77645f00)
#
# ...
